# %%
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt
import numpy as np

# %%
X, y = make_blobs(n_samples=1000, n_features=2, centers=3, cluster_std=1.3)

# %%
fig, ax = plt.subplots(1,1, figsize=(10,6))
ax.scatter(X[:,0],X[:,1])
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.set_xlabel('$x_1$', size=15)
ax.set_ylabel('$x_2$', size=15)
plt.show()
fig.savefig('foto.png')

# %%
X
# Out:
# array([[ 6.3896625 ,  5.45935723],
#        [ 5.7340824 ,  8.12195826],
#        [-4.66869625,  3.39622253],
#        ...,
#        [ 8.17135417,  6.44785282],
#        [ 4.78864176, -2.57626336],
#        [ 8.51784621,  5.70929524]])

# %%
#calcular distancia euclidiana
def dis_eucl(a, b):
  return np.sqrt(sum((a - b)**2))

# %%
#escoger los centroides, k=num_centroides
centroides = {} #centroides
k = 3 #num_centroides
num_iteraciones = 100
for i in range(k):
  centroides[i] = X[np.random.choice(len(X))]

for i in range(num_iteraciones):
  #distancias
  distances = {}
  for pos, dato in enumerate(X):
    distances[pos] = []
    for _ , centroide in centroides.items():
      distances[pos].append(dis_eucl(centroide, dato))

  #asignación
  puntos_centroides = {}

  for i in range(k):
    puntos_centroides[i] = []

  for dato, dists in distances.items():
    puntos_centroides[dists.index(min(dists))].append(X[dato])

  #nuevos centroides

  for cent, datos in puntos_centroides.items():
    centroides[cent] = np.average(datos, axis=0)

# %%
x_0 = np.vstack(puntos_centroides[0])
x_1 = np.vstack(puntos_centroides[1])
x_2 = np.vstack(puntos_centroides[2])

# %%
fig, ax = plt.subplots(1,1, figsize=(10,6))
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.set_xlabel('$x_1$', size=15)
ax.set_ylabel('$x_2$', size=15)
ax.scatter(x_0[:,0],x_0[:,1])
ax.scatter(x_1[:,0],x_1[:,1])
ax.scatter(x_2[:,0],x_2[:,1])
ax.scatter(centroides[0][0],centroides[0][1], marker='x',color='k')
ax.scatter(centroides[1][0],centroides[1][1], marker='x',color='k')
ax.scatter(centroides[2][0],centroides[2][1], marker='x',color='k')
fig.savefig('foto2.png')
plt.show()

# %%
plt.scatter(X[y==0,0],X[y==0,1])
plt.scatter(X[y==1,0],X[y==1,1])
plt.scatter(X[y==2,0],X[y==2,1])
plt.scatter(centroides[0][0],centroides[0][1], marker='x',color='white')
plt.scatter(centroides[1][0],centroides[1][1], marker='x',color='white')
plt.scatter(centroides[2][0],centroides[2][1], marker='x',color='white')

# %%
centroides
# Out:
# [array([4.26397311, 0.2384072 ]),
#  array([-5.16081073,  5.23537909]),
#  array([7.26383916, 8.10087086])]

# %%
a = np.array([1, 2, 3])
b = np.array([3, 4, 5])

# %%
dis_eucl(a, b)
# Out:
# 3.4641016151377544
